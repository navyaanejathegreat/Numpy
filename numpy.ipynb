# %%
import numpy as np

# %%
arr_1d= np.array([1,2,3,4])
print(f"1D Array:{arr_1d}")
# Out:
# 1D Array:[1 2 3 4]

# %%
# we have taken two lists here to from a 2D array and it gave an error because it takes only one list as an input
arr_2d=np.array([1,2,3,4],[5,6,7,8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # we have taken two lists here to from a 2D array
# ----> 3 arr_2d=np.array([1,2,3,4],[5,6,7,8])
#
# TypeError: Field elements must be 2- or 3-tuples, got '5'

# %%
#we will instead take a list that hs two lists in it
arr_2d=np.array([[1,2,3,4],[5,6,7,8]])
print(f"2D Array:{arr_2d}")
# Out:
# 2D Array:[[1 2 3 4]
#  [5 6 7 8]]
